# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Ім'я": [
        "Анна", "Іван", "Олег", "Марія", "Дмитро",
        "Софія", "Максим", "Юлія", "Андрій", "Катерина",
        "Владислав", "Оксана", "Назар", "Ірина", "Павло",
        "Тетяна", "Роман", "Аліна", "Богдан", "Вікторія",
        "Ярослав", "Христина", "Василь", "Олена", "Микита",
        "Дарина", "Артем", "Єлизавета", "Степан", "Вероніка"
    ],

    "Вік": [
        18, 19, 20, 18, 21,
        19, 20, 18, 22, 19,
        21, 20, 18, 19, 22,
        20, 21, 18, 19, 20,
        21, 18, 20, 19, 22,
        18, 21, 20, 19, 18
    ],

    "Години підготовки": [
        12, 18, 10, 20, 25,
        15, 17, 9, 22, 16,
        28, 13, 11, 19, 24,
        14, 21, 8, 18, 23,
        26, 10, 15, 17, 27,
        12, 20, 16, 13, 19
    ],

    "Кількість пропусків": [
        2, 1, 5, 0, 1,
        3, 2, 6, 0, 2,
        1, 4, 5, 2, 0,
        3, 1, 7, 2, 0,
        1, 6, 3, 2, 0,
        4, 1, 2, 5, 1
    ],

    "Підсумкова оцінка": [
        82, 91, 74, 95, 98,
        84, 87, 69, 96, 85,
        99, 78, 72, 88, 97,
        81, 93, 65, 86, 94,
        100, 70, 83, 89, 98,
        79, 92, 84, 76, 90
    ]
}

data_info_df = pd.DataFrame(data)
data_info_df
# Out:
#          Ім'я  Вік  Години підготовки  Кількість пропусків  Підсумкова оцінка
# 0        Анна   18                 12                    2                 82
# 1        Іван   19                 18                    1                 91
# 2        Олег   20                 10                    5                 74
# 3       Марія   18                 20                    0                 95
# 4      Дмитро   21                 25                    1                 98
# 5       Софія   19                 15                    3                 84
# 6      Максим   20                 17                    2                 87
# 7        Юлія   18                  9                    6                 69
# 8      Андрій   22                 22                    0                 96
# 9    Катерина   19                 16                    2                 85
# 10  Владислав   21                 28                    1                 99
# ...

# %%
print("Перші 5 рядків")
print(data_info_df.head(5))
# Out:
# Перші 5 рядків
#      Ім'я  Вік  Години підготовки  Кількість пропусків  Підсумкова оцінка
# 0    Анна   18                 12                    2                 82
# 1    Іван   19                 18                    1                 91
# 2    Олег   20                 10                    5                 74
# 3   Марія   18                 20                    0                 95
# 4  Дмитро   21                 25                    1                 98

# %%
print("Останні 5 рядків")
print(data_info_df.tail(5))
# Out:
# Останні 5 рядків
#          Ім'я  Вік  Години підготовки  Кількість пропусків  Підсумкова оцінка
# 25     Дарина   18                 12                    4                 79
# 26      Артем   21                 20                    1                 92
# 27  Єлизавета   20                 16                    2                 84
# 28     Степан   19                 13                    5                 76
# 29   Вероніка   18                 19                    1                 90

# %%
print("Рандомні 5 рядків")
print(data_info_df.sample(5))
# Out:
# Рандомні 5 рядків
#          Ім'я  Вік  Години підготовки  Кількість пропусків  Підсумкова оцінка
# 18     Богдан   19                 18                    2                 86
# 6      Максим   20                 17                    2                 87
# 10  Владислав   21                 28                    1                 99
# 2        Олег   20                 10                    5                 74
# 17      Аліна   18                  8                    7                 65

# %%
print("Інформація")
print(data_info_df.info())
# Out:
# Інформація
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ім'я                 30 non-null     str
#  1   Вік                  30 non-null     int64
#  2   Години підготовки    30 non-null     int64
#  3   Кількість пропусків  30 non-null     int64
#  4   Підсумкова оцінка    30 non-null     int64
# dtypes: int64(4), str(1)
# memory usage: 1.3 KB
# None

# %%
print("Опис даних")
print(data_info_df.describe())
# Out:
# Опис даних
#              Вік  Години підготовки  Кількість пропусків  Підсумкова оцінка
# count  30.000000          30.000000            30.000000          30.000000
# mean   19.600000          17.266667             2.400000          85.833333
# std     1.328728           5.564254             2.010318           9.748858
# min    18.000000           8.000000             0.000000          65.000000
# 25%    18.250000          13.000000             1.000000          79.500000
# 50%    19.500000          17.000000             2.000000          86.500000
# 75%    20.750000          20.750000             3.750000          93.750000
# max    22.000000          28.000000             7.000000         100.000000

# %%
print("Середнє арифметичне оцінок")
print(data_info_df["Підсумкова оцінка"].mean())
# Out:
# Середнє арифметичне оцінок
# 85.83333333333333

# %%
print("Медіана оцінок")
print(data_info_df["Підсумкова оцінка"].median())
# Out:
# Медіана оцінок
# 86.5

# %%
print("Мода оцінок")
print((data_info_df["Підсумкова оцінка"].mode()).to_list())
# Out:
# Мода оцінок
# [84, 98]

# %%
print("Дисперсія оцінок")
print(data_info_df["Підсумкова оцінка"].var())
# Out:
# Дисперсія оцінок
# 95.04022988505749

# %%
print("Стандартне відхилення оцінок")
print(data_info_df["Підсумкова оцінка"].std())
# Out:
# Стандартне відхилення оцінок
# 9.748857875928723
